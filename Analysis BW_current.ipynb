# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
pip install pandoc
# Out:
# Collecting pandoc
#   Downloading pandoc-2.3.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting plumbum
#   Downloading plumbum-1.8.1-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 5.7 MB/s eta 0:00:00
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.1 MB/s eta 0:00:00
# Building wheels for collected packages: pandoc
#   Building wheel for pandoc (setup.py) ... done
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33286 sha256=1d82bb4d884e565ccc90aeeecc7f6faf5b8daa69c31538804e781487b78b5031
#   Stored in directory: /Users/lindsey/Library/Caches/pip/wheels/76/27/c2/c26175310aadcb8741b77657a1bb49c50cc7d4cdbf9eee0005
# Successfully built pandoc
# Installing collected packages: ply, plumbum, pandoc
# Successfully installed pandoc-2.3 plumbum-1.8.1 ply-3.11
#
# [notice] A new release of pip available: 22.1.2 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
cd Downloads
# Out:
# /Users/lindsey/Downloads

# %%
df = pd.read_excel("Self-Care Raw Data Randomized.xlsx")

# %%
df.shape
# Out:
# (400, 13)

# %%
data = df.groupby(["date","contents"]).size()

# %%
df.date.value_counts()
# Out:
# 2023-01-01 01:49:25    1
# 2022-11-07 15:17:21    1
# 2022-11-06 01:38:27    1
# 2022-11-06 05:57:03    1
# 2022-11-06 13:05:58    1
#                       ..
# 2022-12-04 22:22:16    1
# 2022-12-04 22:42:27    1
# 2022-12-05 13:33:54    1
# 2022-12-05 14:09:06    1
# 2022-10-06 07:37:11    1
# Name: date, Length: 400, dtype: int64

# %%
# datas = df['date'].value_counts().sort_index()

# %%
import datetime as dt

# %%
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['Day_of_week'] = df['date'].apply(lambda x: x.weekday())

# %%
df.Day_of_week.value_counts()
# Out:
# 3    70
# 0    62
# 5    61
# 1    56
# 6    55
# 4    52
# 2    44
# Name: Day_of_week, dtype: int64

# %%
df["Day_Name"] = df['date'].dt.day_name()

# %%
df["Time_of_Day"] = df['date'].dt.hour
df["Time_of_Day"].value_counts()
# Out:
# 13    25
# 16    24
# 15    24
# 11    24
# 17    22
# 1     21
# 12    21
# 4     21
# 21    21
# 18    19
# 14    18
# 2     17
# 22    17
# 3     14
# 9     14
# 8     13
# 5     13
# 10    12
# 19    11
# 6     11
# 23    11
# 20    10
# 0     10
# 7      7
# Name: Time_of_Day, dtype: int64

# %%
df["Time_of_Day_Str"] = df["Time_of_Day"].astype('str')

# %%
df = df.replace({'Time_of_Day_Str' : {'0':'12am', '1':'1am', '2':'2am', '3':'3am', '4':'4am', '5':'5am',
                                     '6':'6am', '7':'7am', '8':'8am', '9':'9am', '10':'10am', '11':'11am',
                                     '12':'12pm', '13':'1pm', '14':'2pm', '15':'3pm', '16':'4pm', '17':'5pm',
                                     '18':'6pm', '19':'7pm', '20':'8pm', '21':'9pm', '22':'10pm', '23':'11pm'}})

# %%
df = df.sort_values('Day_Name')

# %%
df["Time_of_Day_Str"].value_counts()
# Out:
# 1pm     25
# 4pm     24
# 3pm     24
# 11am    24
# 5pm     22
# 1am     21
# 12pm    21
# 4am     21
# 9pm     21
# 6pm     19
# 2pm     18
# 2am     17
# 10pm    17
# 3am     14
# 9am     14
# 8am     13
# 5am     13
# 10am    12
# 7pm     11
# 6am     11
# 11pm    11
# 8pm     10
# 12am    10
# 7am      7
# Name: Time_of_Day_Str, dtype: int64

# %%
df['Day_Name'] = pd.Categorical(df['Day_Name'], categories=['Monday','Tuesday','Wednesday','Thursday','Friday',
                                                           'Saturday','Sunday'], ordered=True)

# %%
df['Day_Name']
# Out:
# 0        Sunday
# 1        Sunday
# 2      Saturday
# 3      Saturday
# 4      Saturday
#          ...
# 395      Friday
# 396    Thursday
# 397    Thursday
# 398    Thursday
# 399    Thursday
# Name: Day_Name, Length: 400, dtype: category
# Categories (7, object): ['Monday' < 'Tuesday' < 'Wednesday' < 'Thursday' < 'Friday' < 'Saturday' < 'Sunday']

# %%
df['Time_of_Day'] = pd.Categorical(df['Time_of_Day'], categories=['12am','1am','2am','3am','4am','5am','6am','7am',
                                                                 '8am', '9am', '10am','11am','12pm','1pm','2pm',
                                                                 '3pm','4pm','5pm','6pm','7pm','8pm','9pm','10pm',
                                                                 '11pm'], ordered=True)

# %%
df['Time_of_Day'] = df['Time_of_Day'].astype('str')

# %%
df['Time_of_Day']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 395    NaN
# 396    NaN
# 397    NaN
# 398    NaN
# 399    NaN
# Name: Time_of_Day, Length: 400, dtype: category
# Categories (24, object): ['12am' < '1am' < '2am' < '3am' ... '8pm' < '9pm' < '10pm' < '11pm']

# %%
df['Day_Name'].sort_index().value_counts()
# Out:
# Thursday     70
# Monday       62
# Saturday     61
# Tuesday      56
# Sunday       55
# Friday       52
# Wednesday    44
# Name: Day_Name, dtype: int64

# %%
df.columns
# Out:
# Index(['url', 'date', 'Title', 'contents', 'Domain', 'Sentiment', 'Emotion',
#        'Country', 'Author', 'Day_of_week', 'Day_Name'],
#       dtype='object')

# %%
# Out:
# Joy        262
# Sadness     35
# Anger       24
# Fear        12
# Disgust      7
# Name: Emotion, dtype: int64

# %%
# plot occurences of contents column by aggregate day of the week within 
m = df.groupby(df.Day_Name,sort=False)['contents'].count().plot(kind="bar")
plt.show()

# %%
dfDate = df.copy()

# %%
dfDate = dfDate[(dfDate['date'] > "2022-10-06") & (dfDate['date'] < "2023-01-01")]

# %%
dfDate.Day_Name.value_counts(), df.Day_Name.value_counts()
# Out:
# (Thursday     70
#  Monday       62
#  Saturday     61
#  Tuesday      56
#  Sunday       53
#  Friday       52
#  Wednesday    44
#  Name: Day_Name, dtype: int64,
#  Thursday     70
#  Monday       62
#  Saturday     61
#  Tuesday      56
#  Sunday       55
#  Friday       52
#  Wednesday    44
#  Name: Day_Name, dtype: int64)

# %%
dfDate['Formatted_Date'] = pd.to_datetime(dfDate['date'], format='%Y-%m-%d')

# %%
filtered_df = dfDate.loc[(dfDate['date'] >= '2022-10-05')
                     & (dfDate['date'] < '2023-01-02')]

# %%
filtered_df.shape
# Out:
# (398, 14)

# %%
dfDate = dfDate[(dfDate['Emotion'] == 'Joy')]

# %%
# Out:
#                                                    url                date  \
# 0    https://www.reddit.com/r/lgbt/comments/1000wfz... 2023-01-01 01:49:25
# 1    http://twitter.com/Thatcoolwaterm1/statuses/16... 2023-01-01 01:20:52
# 2    http://twitter.com/Pozz_i_i/statuses/160932008... 2022-12-31 22:46:21
# 3    http://twitter.com/smhimh/statuses/16092586878... 2022-12-31 18:42:24
# 4    http://twitter.com/melanielinette_/statuses/16... 2022-12-31 18:15:45
# ..                                                 ...                 ...
# 395  http://twitter.com/KoomeMapesa/statuses/157846... 2022-10-07 19:13:24
# 396  http://twitter.com/honkdi4u/statuses/157816081... 2022-10-06 23:10:32
# 397  http://twitter.com/Calyria3/statuses/157798245... 2022-10-06 11:21:49
# 398  http://twitter.com/hondadude99/statuses/157797... 2022-10-06 10:50:26
# 399  http://twitter.com/yeeshamg9231/statuses/15779... 2022-10-06 07:37:11
#
#                                                  Title  \
# 0                     new year old me (comic) HEAVY TW
# 1    RT @mxxnquakes happy new year! wish your 2023 ...
# 2    RT @_Pammy_DS_ avoiding people who repeatedly ...
# 3    I finished my first quilt!!! The sense of acco...
# 4    RT @niicole__nicole my main two goals for next...
# ..                                                 ...
# 395  RT @sholla_saddam Removing alcohol from your l...
# 396                               @stvrbee self love<3
# 397  RT @IamKiraJ So much of the pain I’ve experien...
# 398  RT @_Pammy_DS_ Removing yourself from anywhere...
# 399  RT @PsychologyF_ Psychology says, Smart people...
#
#                                               contents       Domain Sentiment  \
# 0    Hey sometimes the best we can do in a day is b...   reddit.com  positive
# 1    RT @mxxnquakes happy new year! wish your 2023 ...  twitter.com  positive
# 2    RT @_Pammy_DS_ avoiding people who repeatedly ...  twitter.com  negative
# 3    I finished my first quilt!!! The sense of acco...  twitter.com  positive
# 4    RT @niicole__nicole my main two goals for next...  twitter.com  negative
# ..                                                 ...          ...       ...
# 395  RT @sholla_saddam Removing alcohol from your l...  twitter.com   neutral
# 396                               @stvrbee self love<3  twitter.com  positive
# 397  RT @IamKiraJ So much of the pain I’ve experien...  twitter.com  positive
# 398  RT @_Pammy_DS_ Removing yourself from anywhere...  twitter.com   neutral
# 399  RT @PsychologyF_ Psychology says, Smart people...  twitter.com   neutral
#
#      Emotion                   Country           Author  Day_of_week  \
# 0        Joy                       NaN     discoleopard            6
# 1        Joy                  Thailand  Thatcoolwaterm1            6
# 2      Anger                       NaN         Pozz_i_i            5
# 3        Joy                    Canada           smhimh            5
# 4    Sadness                       NaN  melanielinette_            5
# ..       ...                       ...              ...          ...
# 395      Joy                     Kenya      KoomeMapesa            4
# 396      Joy                       NaN         honkdi4u            3
# 397  Sadness  United States of America         Calyria3            3
# 398      Joy                       NaN      hondadude99            3
# 399  Sadness                       NaN     yeeshamg9231            3
#
#      Day_Name  Time_of_Day Time_of_Day_Str
# 0      Sunday            1             1am
# 1      Sunday            1             1am
# 2    Saturday           22            10pm
# 3    Saturday           18             6pm
# 4    Saturday           18             6pm
# ..        ...          ...             ...
# 395    Friday           19             7pm
# 396  Thursday           23            11pm
# 397  Thursday           11            11am
# 398  Thursday           10            10am
# 399  Thursday            7             7am
#
# [400 rows x 13 columns]

# %%
dfDate.shape
# Out:
# (262, 14)

# %%
dfDate = dfDate.rename(columns={"Day_Name":"Day of the Week", "Time_of_Day":"Time of Day"})

# %%
dfDate.columns
# Out:
# Index(['url', 'date', 'Title', 'contents', 'Domain', 'Sentiment', 'Emotion',
#        'Country', 'Author', 'Day_of_week', 'Day of the Week', 'Time of Day',
#        'Time_of_Day_Str'],
#       dtype='object')

# %% [markdown]
# ### Plot by Day of the Week

# %%
# plot occurences of contents column by aggregate day of the week within - for Emotion "Joy"
m = dfDate.groupby(dfDate['Day of the Week'],sort=False)['contents'].count().plot(kind="bar", color=(.35, 0.62, 0.63))
plt.show()

# %% [markdown]
# ### Plot by Time of Day

# %%
# plot occurences of contents column by aggregate day of the week within - for Emotion "Joy"
m = dfDate.groupby(dfDate['Time of Day'],sort=True)['contents'].count().plot(kind="bar", color=(.35, 0.62, 0.63))
plt.show()

# %%
# x = ['12am','1am','2am','3am','4am','5am','6am','7am','8am', '9am', '10am','11am','12pm','1pm','2pm',
#      '3pm','4pm','5pm','6pm','7pm','8pm','9pm','10pm','11pm']

# plt.set_xticklabels(x)

# %%
dfCommentsCount = pd.DataFrame()
dfCommentsCount['Comment_Counts'] = ''

# %%
dfCommentsCount.Comment_Counts = df.contents.value_counts()

# %%
dfCommentsCount.to_csv("Comment_Counts.csv")

# %% [markdown]
# ### Word Cloud Creation

# %%
# pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
df.contents.isna().sum()
# Out:
# 0

# %%
comments = " ".join(df.contents.tolist())
comments
# Out:
# 'Hey sometimes the best we can do in a day is brush our teeth. Just one self care thing a day, no matter how small, is everything. Your art is amazing! Happy new year RT @mxxnquakes happy new year! wish your 2023 is full of happiness, smiles and positive energy, remember to love yourself the most and let self-love grows, cheers 🖤 RT @_Pammy_DS_ avoiding people who repeatedly trigger your mental health and lower your vibe is top tier self-care. I finished my first quilt!!! The sense of accomplishment and self love i have for myself is at an all time high lol so many mistakes but theyre all adorable and fine, its my blanket, no worries! https://t.co/47l78HxYtd RT @niicole__nicole my main two goals for next year is money management & SELF CARE heavy on that 😭 I’M SORRY BROTHER BECAUSE I UPVOTED AND RUINED YOUR SWEET 420 BUT I HAD TO BECAUSE GIVING IMAGE TRANSCRIPTIONS IS SUCH A BADASS WAY TO HELP OUR SIGHT IMPAIRED BROTHERS AND SISTERS TO BE INCLUDED AND CRANK THEIR HOGS WITH THE REST OF US. CONGRATS ON THE TRT AND SELF LOVE BROTHER!! AROOOOOOOO RT @lukewaltham May 2023 been a year of more self love and self care. RT @7for_Omankind The self care bill when you do everything in one day is…..criminal RT @niicole__nicole my main two goals for next year is money management & SELF CARE heavy on that 😭 RT @niicole__nicole my main two goals for next year is money management & SELF CARE heavy on that 😭 RT @CHINATHE8BAR Minghao\'s original quote reads: Whether you are slim or a bit curvy, you should have the idea of trying to stay healthy because you love yourself, skinny or chubby, it is for your personal health (as keeping healthy is part of self-love), not for visual aesthetics. https://t.co/voasegvxah RT @nothingexplaind This is a rewrite of a rewrite of a meme where the old rewrite preserved "Someone is WRONG on the Internet" while adding the new ending. Both memes are statements of self-care, that instead of staying up late getting into Internet arguments/maintenance, the poster is moving on. RT @niicole__nicole my main two goals for next year is money management & SELF CARE heavy on that 😭 RT @CHINATHE8BAR Minghao\'s original quote reads: Whether you are slim or a bit curvy, you should have the idea of trying to stay healthy because you love yourself, skinny or chubby, it is for your personal health (as keeping healthy is part of self-love), not for visual aesthetics. https://t.co/voasegvxah RT @anahiox Happy Friday everyone! Friday is known for Venus energy which is everyone tends to have a Good Friday. Venus in Capricorn so u can expect luxury self-care today. @ColorsTV @ShivThakare9 Self-love is the peace of mind to stay present! #BBKingShiv RT @ktoofantastic I go clubbing,i go out to dinner, i go out to museums, i go on vacation, i also stay home when i feel like it and do self care and watch movies.. idk why ppl be acting like you can’t live both life’s tf😭 RT @goatuna CW: hypno and leather gear Sink, Submit, Self-care. The tanuki commands it. https://t.co/dfZod2fJC7 RT @Lubchansky adding "i\'m smol bean who needs self care" as the fifteenth Common Feature of Fascism RT @Ellemilton Am I the only one Bella surprised this day? 😂 I was sooooo proud of her, she had one of the best paintings and she taught us the importance of self love. CARTEL 26 BELLAS THROWBACKS CARTEL 26 BELLAS THROWBACKS https://t.co/x0tTxUUUDs RT @MillsReggie Blocking, muting, deleting, unfollowing is self care. RT @wealth_director Blocking, muting, deleting, unfollowing, is self care. RT @Noorthevirgo 2023 smelling like alot of gym gains and self love RT @strong_leaders Self-care is an essential part of your well-being. Take time to discover what helps you feel good and recharge. I’m going to check him out. I’ve been listening Matthew Hussey’s “Love. Life.” Podcast on Spotify. I recommend it for grieving heartbreak, navigating dating, and for self love and empowerment. I continue to think this is King\'s worst book. I’m all for loving my body. But I can’t sta ...

# %%
## If you'd like a different word cloud, just Shift+Enter this cell an the following cell to populate a new one
word_cloud = WordCloud(collocations = False, background_color = 'white', width=800,height=650).generate(comments)

# %%
# cloud = WordCloud(width=200/my_dpi,height=150/my_dpi)
# plt.imshow(cloud.generate_from_frequencies(t))
# plt.savefig('c.png', dpi=my_dpi)
# plt.clf()

plt.figure( figsize=(20,10) )
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
